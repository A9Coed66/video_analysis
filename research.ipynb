# %%
import numpy
import soundfile as sf
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

# input can be a URL or a local path
input = 'https://modelscope.cn/api/v1/models/damo/speech_mossformer2_separation_temporal_8k/repo?Revision=master&FilePath=examples/mix_speech1.wav'
separation = pipeline(
   Tasks.speech_separation,
   model='damo/speech_mossformer2_separation_temporal_8k')
result = separation(input)
for i, signal in enumerate(result['output_pcm_list']):
    save_file = f'output_spk{i}.wav'
    sf.write(save_file, numpy.frombuffer(signal, dtype=numpy.int16), 8000)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import numpy
#       2 import soundfile as sf
# ----> 3 from modelscope.pipelines import pipeline
#       4 from modelscope.utils.constant import Tasks
#       6 # input can be a URL or a local path
#
# File c:\Users\ADMIN\miniconda3\Lib\site-packages\modelscope\pipelines\__init__.py:4
#       1 # Copyright (c) Alibaba, Inc. and its affiliates.
#       3 from . import audio, cv, multi_modal, nlp
# ----> 4 from .base import Pipeline
#       5 from .builder import pipeline
#
# File c:\Users\ADMIN\miniconda3\Lib\site-packages\modelscope\pipelines\base.py:16
#      13 from packaging import version
#      15 from modelscope.models.base import Model
# ---> 16 from modelscope.msdatasets import MsDataset
#      17 from modelscope.outputs import TASK_OUTPUTS, ModelOutputBase
#      18 from modelscope.pipeline_inputs import TASK_INPUTS, check_input_type
#
# File c:\Users\ADMIN\miniconda3\Lib\site-packages\modelscope\msdatasets\__init__.py:2
#       1 # Copyright (c) Alibaba, Inc. and its affiliates.
# ----> 2 from modelscope.msdatasets.ms_dataset import MsDataset
#
# File c:\Users\ADMIN\miniconda3\Lib\site-packages\modelscope\msdatasets\ms_dataset.py:24
#      21 from modelscope.msdatasets.dataset_cls.custom_datasets.builder import \
#      22     build_custom_dataset
#      23 from modelscope.msdatasets.utils.delete_utils import DatasetDeleteManager
# ---> 24 from modelscope.msdatasets.utils.hf_datasets_util import load_dataset_with_ctx
#      25 from modelscope.msdatasets.utils.upload_utils import DatasetUploadManager
#      26 from modelscope.preprocessors import build_preprocessor
#
# File c:\Users\ADMIN\miniconda3\Lib\site-packages\modelscope\msdatasets\utils\hf_datasets_util.py:31
#      29 from datasets.exceptions import DataFilesNotFoundError, DatasetNotFoundError
#      30 from datasets.info import DatasetInfosDict
# ---> 31 from datasets.load import (
#      32     ALL_ALLOWED_EXTENSIONS, BuilderConfigsParameters,
#      33     CachedDatasetModuleFactory, DatasetModule,
#      34     HubDatasetModuleFactoryWithoutScript,
#      35     HubDatasetModuleFactoryWithParquetExport,
#      36     HubDatasetModuleFactoryWithScript, LocalDatasetModuleFactoryWithoutScript,
#      37     LocalDatasetModuleFactoryWithScript, PackagedDatasetModuleFactory,
#      38     create_builder_configs_from_metadata_configs, get_dataset_builder_class,
#      39     import_main_class, infer_module_for_data_files, files_to_hash,
#      40     _get_importable_file_path, resolve_trust_remote_code, _create_importable_file, _load_importable_file,
#      41     init_dynamic_modules)
#      42 from datasets.naming import camelcase_to_snakecase
#      43 from datasets.packaged_modules import (_EXTENSION_TO_MODULE,
#      44                                        _MODULE_TO_EXTENSIONS,
#      45                                        _PACKAGED_DATASETS_MODULES)
#
# ImportError: cannot import name 'ALL_ALLOWED_EXTENSIONS' from 'datasets.load' (c:\Users\ADMIN\miniconda3\Lib\site-packages\datasets\load.py)

# %%
# !pip install oss2
# Out:
# Collecting oss2
#   Downloading oss2-2.19.1.tar.gz (298 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests!=2.9.0 in c:\users\admin\miniconda3\lib\site-packages (from oss2) (2.32.5)
# Collecting crcmod>=1.7 (from oss2)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pycryptodome>=3.4.7 (from oss2)
#   Using cached pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six in c:\users\admin\miniconda3\lib\site-packages (from oss2) (1.17.0)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in c:\users\admin\miniconda3\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\admin\miniconda3\lib\site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\admin\miniconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\miniconda3\lib\site-packages (from requests!=2.9.0->oss2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniconda3\lib\site-packages (from requests!=2.9.0->oss2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\miniconda3\lib\site-packages (from requests!=2.9.0->oss2) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\miniconda3\lib\site-packages (from requests!=2.9.0->oss2) (2026.2.25)
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (pyproject.toml): started
#   Building wheel for oss2 (pyproject.toml): finished with status 'done'
#   Created wheel for oss2: filename=oss2-2.19.1-py3-none-any.whl size=124052 sha256=2fa28d22a59b1276263d638e4e4a4a6918e26eb3db6dc514e81b965adb9b7a16
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\68\a5\c4\ae8c461fdb669b208f748dd02fab0d28c052edbb3333394c8c
#   Building wheel for aliyun-python-sdk-core (pyproject.toml): started
#   Building wheel for aliyun-python-sdk-core (pyproject.toml): finished with status 'done'
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535434 sha256=23c13de5677bce325a8777dc7061cbf4cfd6582396d5653db6cd332c51e952a2
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\b5\ba\72\618a9c3b436edb6c2cc25e6e3b41eb298cf8406e234a1e0a18
#   Building wheel for crcmod (pyproject.toml): started
#   Building wheel for crcmod (pyproject.toml): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-cp313-cp313-win_amd64.whl size=24742 sha256=654ca688569aac65f690974f063da099bc98ed41fe8beedec0dfdebcdba0244d
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c5\b4\7d\51d3485a8022501c7f7dba78b6c945088ff93d40142c9a96f4
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: crcmod, pycryptodome, jmespath, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2
#
#    ------ --------------------------------- 1/6 [pycryptodome]
#    ------ --------------------------------- 1/6 [pycryptodome]
#    ------ --------------------------------- 1/6 [pycryptodome]
#    ------ --------------------------------- 1/6 [pycryptodome]
#    -------------------- ------------------- 3/6 [aliyun-python-sdk-core]
#    -------------------- ------------------- 3/6 [aliyun-python-sdk-core]
#    -------------------- ------------------- 3/6 [aliyun-python-sdk-core]
#    -------------------------- ------------- 4/6 [aliyun-python-sdk-kms]
#    --------------------------------- ------ 5/6 [oss2]
#    ---------------------------------------- 6/6 [oss2]
#
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 crcmod-1.7 jmespath-0.10.0 oss2-2.19.1 pycryptodome-3.23.0
